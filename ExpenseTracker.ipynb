# %% [markdown]
# Expense Tracker

# %%
expenses = [{'Category': 'Dry Grocery', 'amount': 300}, {'Category': 'Fruits', 'amount':200}, {'Category': 'Vegetables', 'amount':150}, {'Category': 'Fruits', 'amount': 250}]

# %%
expenses1 = expenses
total_expense = sum(item['amount'] for item in expenses1)
print('Total Expenses:', total_expense)
# Out:
# Total Expenses: 900

# %%
category_totals = {}
for item in expenses:
    category = item['Category']
    amount = item['amount']
     
    if Category in category_totals:
        category_totals[Category] += amount
    else:
        category_totals[Category] = amount
  
print(category_totals)
# Out:
# {'Fruits': 900}

# %%
category_totals = {}  #


for item in expenses:
    category = item['Category']  # key name is lowercase
    amount = item['amount']
    
    if category in category_totals:
        category_totals[category] += amount  # use variable, not string
    else:
        category_totals[category] = amount

print(category_totals)
# Out:
# {'Dry Grocery': 300, 'Fruits': 450, 'Vegetables': 150}

# %%
category_totals = {}  # all lowercase

for item in expenses:
    category = item['Category']  # match the key in your dictionary
    amount = item['amount']
    
    if category in category_totals:
        category_totals[category] += amount
    else:
        category_totals[category] = amount

print(category_totals)

sum(category_totals.values())
# Out:
# {'Dry Grocery': 300, 'Fruits': 450, 'Vegetables': 150}
# 900

# %%
max(category_totals.values())
# Out:
# 450
