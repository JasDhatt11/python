# %%
students = {"Jas": 98, "Raj": 80, "Aman": 75, "Kirat": 48}
students.values()
# Out:
# dict_values([98, 80, 75, 48])

# %%
sum(students.values())
# Out:
# 301

# %%
len(students)
# Out:
# 4

# %%
average = sum(students.values())/len(students)
print('Class Average', average)
# Out:
# Class Average 75.25

# %%
max(students.values())
# Out:
# 98

# %%
students.items()
highest = max(students.values())
for name, mark in students.items():
    if (mark  == highest):
        print('topper:', name)
# Out:
# topper: Jas

# %%
count = 0
for mark in students.values():
    if (mark > 50):
        print('student passed')
    else:
        print('student failed')
# Out:
# student passed
# student passed
# student passed
# student failed

# %%
count = 0

for mark in students.values():
    
    if (mark > 50):
        count += 1
print('Number ofstudent passed', count)
   
print('number of student failed', len(students)-count)
# Out:
# Number ofstudent passed 3
# number of student failed 1

# %%
students = {"Jas": 98, "Raj": 80, "Aman": 75, "Kirat": 48}
students.values()

sum(students.values())
len(students)

average = sum(students.values())/len(students)
print('Class Average', average)

max(students.values())
students.items()
highest = max(students.values())
for name, mark in students.items():
    if (mark  == highest):
        print('topper:', name)
        
count = 0
for mark in students.values():
    if (mark > 50):
        print(name, 'passed')
    else:
        print(name, 'failed')

        
for mark in students.values():
    
    if (mark > 50):
        count += 1
print('Number ofstudent passed', count)
   
print('number of student failed', len(students)-count)
# Out:
# Class Average 75.25
# topper: Jas
# Kirat passed
# Kirat passed
# Kirat passed
# Kirat failed
# Number ofstudent passed 3
# number of student failed 1
